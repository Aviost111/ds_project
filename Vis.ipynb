# %%
import pandas as pd 
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('cleaned_glassdoor_dataset.csv',index_col=0)
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
df_n = pd.get_dummies(df)

df_n
# Out:
#      Rating  Founded  Min_Salary  Max_Salary  Avg Salary  Is_Headquarters  \
# 0       3.8     1973        53.0        91.0        72.0                0
# 1       3.4     1984        63.0       112.0        87.5                0
# 2       4.8     2010        80.0        90.0        85.0                1
# 3       3.8     1965        56.0        97.0        76.5                1
# 4       2.9     1998        86.0       143.0       114.5                1
# ..      ...      ...         ...         ...         ...              ...
# 950     3.9     1830        58.0       111.0        84.5                0
# 951     4.4     2006        72.0       133.0       102.5                0
# 952     2.6     1984        56.0        91.0        73.5                1
# 953     3.2       -1        95.0       160.0       127.5                0
# 955     3.6     1967        61.0       126.0        93.5                0
#
#      Age of Company  Python  Spark  AWS  ...  Job Categories_Data Engineer  \
# ...

# %%
train, test = train_test_split(df_n, test_size=0.2, random_state=777)

# %%
# this is how we will need to split our test later

#X = df_n.drop('Avg Salary', axis=1)
#y = df_n['Avg Salary'].values

#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777)
