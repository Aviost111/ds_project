# %%
import pandas as pd

# %%
df=pd.read_csv('cleaned_glassdoor_dataset.csv')
df=
df
# Out:
#      Unnamed: 0  Unnamed: 0.1  \
# 0             0             0
# 1             1             1
# 2             2             2
# 3             3             3
# 4             4             4
# ..          ...           ...
# 737         950           950
# 738         951           951
# 739         952           952
# 740         953           953
# 741         955           955
#
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 737           Sr Scientist, Immuno-Oncology - Oncology
# 738                               Senior Data Engineer
# 739  Project Scientist - Auton Lab, Robotics Institute
# ...
